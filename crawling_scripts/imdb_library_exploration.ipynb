# %%
# !pip install cinemagoer
# Out:
# Collecting cinemagoer
#   Downloading cinemagoer-2022.12.27-py3-none-any.whl (297 kB)
#      -------------------------------------- 297.2/297.2 kB 4.6 MB/s eta 0:00:00
# Collecting lxml
#   Downloading lxml-4.9.2-cp310-cp310-win_amd64.whl (3.8 MB)
#      ---------------------------------------- 3.8/3.8 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy in c:\users\timos\appdata\local\programs\python\python310\lib\site-packages (from cinemagoer) (1.4.41)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\timos\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy->cinemagoer) (1.1.3.post0)
# Installing collected packages: lxml, cinemagoer
# Successfully installed cinemagoer-2022.12.27 lxml-4.9.2
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imdb import Cinemagoer
import json
# create an instance of the Cinemagoer class
ia = Cinemagoer()

# get a movie
movie = ia.get_movie('0133093')

movie.items()
# Out:
# 2023-02-10 13:47:41,658 ERROR [imdbpy] c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\site-packages\imdb\__init__.py:844: unknown information set "0001000"
# []

# %%
import pandas as pd 
from imdb import Cinemagoer
import json
import warnings
warnings.filterwarnings('ignore')
ia = Cinemagoer()
movie = ia.get_movie('0133093')
movie_data_ =  {
    "imdbID" : movie['imdbID'],
    "original title": movie["original title"],
    "genres": ",".join(movie['genres']) if isinstance(movie['genres'], list) else movie['genres'],
    "countries": ",".join(movie["countries"])if isinstance(movie['countries'], list) else movie['countries'],
    "country codes": ",".join(movie["country codes"]) if isinstance(movie['country codes'], list) else movie['country codes'],
    "box office": movie['box office']["Budget"],
    "certificates": movie['certificates'][17],
    "rating": movie["rating"],
    "votes": movie["votes"],
    "plot outline": movie['plot outline'],
    "year": movie["year"],
    "kind": movie["kind"],
    "full-size cover url": movie['full-size cover url']
  }
df = pd.DataFrame(movie_data_, index=[movie_data_["imdbID"]])
df.drop("imdbID",axis=1, inplace=True)
numbers = [str(i).zfill(7) for i in range(1, 10)]


for i in numbers:
      try:
        movie = ia.get_movie(i)
        movie_data = {
      "imdbID": movie.get('imdbID', 'N/A'),
      "original title": movie.get("original title", 'N/A'),
      "genres": ",".join(movie.get('genres', [])) if isinstance(movie.get('genres', []), list) else movie.get('genres', 'N/A'),
      "countries": ",".join(movie.get("countries", [])) if isinstance(movie.get('countries', []), list) else movie.get('countries', 'N/A'),
      "country codes": ",".join(movie.get("country codes", [])) if isinstance(movie.get('country codes', []), list) else movie.get('country codes', 'N/A'),
      "box office": movie.get("box office", {}).get("Budget", "N/A"),
      "certificates": "N/A",
      "rating": movie.get("rating", 'N/A'),
      "votes": movie.get("votes", 'N/A'),
      "plot outline": movie.get('plot outline', 'N/A'),
      "year": movie.get("year", 'N/A'),
      "kind": movie.get("kind", 'N/A'),
      "full-size cover url": movie.get('full-size cover url', 'N/A')
  }
        try:
          for entry in movie['certificates']:
            if 'germany' in entry.lower():
              rating = entry
              break
          movie_data["certificates"] =  rating
        except:
          movie_data["certificates"] =  "N/A"

        df_to_append = pd.DataFrame(movie_data, index=[movie_data["imdbID"]])
        df_to_append.drop("imdbID",axis=1, inplace=True)
        df = df.append(df_to_append)
        print(f"{movie_data['original title']} crawled")
        
      except Exception as e:
          print(e)
          print(f"Not possible for {i}")
# Out:
# Carmencita crawled
# Le clown et ses chiens crawled
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\timos\Documents\Programming for Data Science\imdb_library_exploration.ipynb Cell 3 in <cell line: 28>()
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> for i in numbers:
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=28'>29</a>       try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a>         movie = ia.get_movie(i)
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a>         movie_data = {
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=31'>32</a>       "imdbID": movie.get('imdbID', 'N/A'),
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=32'>33</a>       "original title": movie.get("original title", 'N/A'),
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=43'>44</a>       "full-size cover url": movie.get('full-size cover url', 'N/A')
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=44'>45</a>   }
#      <a href='vscode-notebook-cell:/c%3A/Users/timos/Documents/Programming%20for%20Data%20Science/imdb_library_exploration.ipynb#W4sZmlsZQ%3D%3D?line=45'>46</a>         try:
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\site-packages\imdb\__init__.py:429, in IMDbBase.get_movie(self, movieID, info, modFunct)
#     427 if modFunct is not None:
#     428     movie.set_mod_funct(modFunct)
# --> 429 self.update(movie, info)
#     430 return movie
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\site-packages\imdb\__init__.py:848, in IMDbBase.update(self, mop, info, override)
#     846     method = lambda *x: {}
#     847 try:
# --> 848     ret = method(mopID)
#     849 except Exception:
#     850     _imdb_logger.critical(
#     851         'caught an exception retrieving or parsing "%s" info set'
#     852         ' for mopID "%s" (accessSystem: %s)',
#     853         i, mopID, mop.accessSystem, exc_info=True
#     854     )
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\site-packages\imdb\parser\http\__init__.py:498, in IMDbHTTPAccessSystem.get_movie_plot(self, movieID)
#     497 def get_movie_plot(self, movieID):
# --> 498     cont = self._retrieve(self.urls['movie_main'] % movieID + 'plotsummary')
#     499     ret = self.mProxy.plot_parser.parse(cont, getRefs=self._getRefs)
#     500     ret['info sets'] = ('plot', 'synopsis')
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\site-packages\imdb\parser\http\__init__.py:392, in IMDbHTTPAccessSystem._retrieve(self, url, size, _noCookies)
#     390 """Retrieve the given URL."""
#     391 self._http_logger.debug('fetching url %s (size: %d)', url, size)
# --> 392 ret = self.urlOpener.retrieve_unicode(url, size=size)
#     393 if PY2 and isinstance(ret, str):
#     394     ret = ret.decode('utf-8')
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\site-packages\imdb\parser\http\__init__.py:234, in IMDbURLopener.retrieve_unicode(self, url, size)
#     232 uopener.addheaders = list(self.addheaders)
#     233 response = uopener.open(url)
# --> 234 content = response.read()
#     235 self._last_url = response.url
#     236 # Maybe the server is so nice to tell us the charset...
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\http\client.py:459, in HTTPResponse.read(self, amt)
#     456     return b""
#     458 if self.chunked:
# --> 459     return self._read_chunked(amt)
#     461 if amt is not None:
#     462     if self.length is not None and amt > self.length:
#     463         # clip the read to the "end of response"
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\http\client.py:582, in HTTPResponse._read_chunked(self, amt)
#     580 try:
#     581     while True:
# --> 582         chunk_left = self._get_chunk_left()
#     583         if chunk_left is None:
#     584             break
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\http\client.py:565, in HTTPResponse._get_chunk_left(self)
#     563     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     564 try:
# --> 565     chunk_left = self._read_next_chunk_size()
#     566 except ValueError:
#     567     raise IncompleteRead(b'')
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\http\client.py:525, in HTTPResponse._read_next_chunk_size(self)
#     523 def _read_next_chunk_size(self):
#     524     # Read the next chunk size from the file
# --> 525     line = self.fp.readline(_MAXLINE + 1)
#     526     if len(line) > _MAXLINE:
#     527         raise LineTooLong("chunk size")
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\timos\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("crawlings\imdb_crawl.csv",index_col="imdbID")

# %%
df
# Out:
#                                      original title             genres  \
# imdbID
# 4                                       Un bon bock    Animation,Short
# 7       Corbett and Courtney Before the Kinetograph        Short,Sport
# 9                                        Miss Jerry            Romance
# 6                                 Chinese Opium Den              Short
# 8            Edison Kinetoscopic Record of a Sneeze  Documentary,Short
# ...                                             ...                ...
# 98                      Place de l'Opéra, 2e aspect  Documentary,Short
# 96                             Place Saint-Augustin  Documentary,Short
# 97                     Place de l'Opéra, 1er aspect  Documentary,Short
# 94                                     Miss de Vere              Short
# 99                             Place de la Bastille  Documentary,Short
#
#             countries country codes  box office certificates  rating  votes  \
# imdbID
# 4              France            fr         NaN          NaN     5.6    179
# 7       United States            us         NaN          NaN     5.4    811
# 9       United States            us         NaN          NaN     5.3    204
# 6       United States            us         NaN          NaN     5.1    177
# 8       United States            us         NaN          NaN     5.4   2091
# ...               ...           ...         ...          ...     ...    ...
# 98             France            fr         NaN          NaN     4.9     37
# 96             France            fr         NaN          NaN     4.0     30
# 97             France            fr         NaN          NaN     4.6     34
# 94             France            fr         NaN          NaN     4.1     33
# 99             France            fr         NaN          NaN     4.3     33
#
#                                              plot outline  year   kind  \
# imdbID
# 4       A wanderer comes into a cabaret in the country...  1892  movie
# 7       James J. Corbett and Peter Courtney meet in a ...  1894  short
# 9       Geraldine (Jerry) Holbrook, a girl of Eastern ...  1894  movie
# 6                                                     NaN  1894  movie
# 8       A man (Edison's assistant) takes a pinch of sn...  1894  movie
# ...                                                   ...   ...    ...
# 98                                                    NaN  1896  movie
# 96                                                    NaN  1896  movie
# 97                                                    NaN  1896  movie
# 94                                                    NaN  1896  movie
# 99                                                    NaN  1896  movie
#
#                                       full-size cover url
# imdbID
# 4       https://m.media-amazon.com/images/M/MV5BOGI5Nj...
# 7       https://m.media-amazon.com/images/M/MV5BODA4ZT...
# 9       https://m.media-amazon.com/images/M/MV5BNTUwNz...
# 6       https://m.media-amazon.com/images/M/MV5BZjNlZT...
# 8       https://m.media-amazon.com/images/M/MV5BNGQ5Mj...
# ...                                                   ...
# 98      https://m.media-amazon.com/images/M/MV5BMjUxMD...
# 96      https://m.media-amazon.com/images/M/MV5BYzE1Mm...
# 97      https://m.media-amazon.com/images/M/MV5BMDI3MW...
# 94      https://m.media-amazon.com/images/M/MV5BMTg1Nm...
# 99      https://m.media-amazon.com/images/M/MV5BYTc4MW...
#
# [99 rows x 12 columns]

# %%
for i in numbers:
    try:
        movie = ia.get_movie(i)
        print(movie)
    except:
        print("No movie found")
# Out:
# Carmencita
# Le clown et ses chiens
# Poor Pierrot
# Un bon bock
# Blacksmith Scene
# Chinese Opium Den
# No movie found
# Edison Kinetoscopic Record of a Sneeze
# Miss Jerry
# Leaving the Factory
# Akrobatisches Potpourri
